# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training. In this notebook, I'll show you how to do this in PyTorch.
#
# As usual, let's start by loading the dataset through torchvision. You'll learn more about torchvision and loading data in a later part. This time we'll be taking advantage of the test set which you can get by setting `train=False` here:
#
# ```python
# testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
# ```
#
# The test set contains images just like the training set. Typically you'll see 10-20% of the original dataset held out for testing and validation with the rest being used for training.

# %%
import torch
from torchvision import datasets, transforms
from torch import nn, optim
import torch.nn.functional as F
import os
import matplotlib.pyplot as plt

# %%
# Setting up the paths
base_data_dir = os.path.abspath('../_data')
f_mnist_data_dir = os.path.join(base_data_dir, 'F_MNIST_data')

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST(f_mnist_data_dir, download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST(f_mnist_data_dir, download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here I'll create a model like normal, using the same one from my solution for part 4.

# %%
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %% [markdown]
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. First I'll do a forward pass with one batch from the test set.

# %%
model = Classifier()

images, labels = next(iter(testloader))
# Get the class probabilities
ps = torch.exp(model(images))
# Make sure the shape is appropriate, we should get 10 class probabilities for 64 examples
print(ps.shape)
# Out:
# torch.Size([64, 10])

# %% [markdown]
# With the probabilities, we can get the most likely class using the `ps.topk` method. This returns the $k$ highest values. Since we just want the most likely class, we can use `ps.topk(1)`. This returns a tuple of the top-$k$ values and the top-$k$ indices. If the highest value is the fifth element, we'll get back 4 as the index.

# %%
top_p, top_class = ps.topk(1, dim=1)
# Look at the most likely classes for the first 10 examples
print(top_class[:10])
# Out:
# tensor([[8],
#         [3],
#         [8],
#         [8],
#         [0],
#         [8],
#         [8],
#         [3],
#         [8],
#         [3]])

# %% [markdown]
# Now we can check if the predicted classes match the labels. This is simple to do by equating `top_class` and `labels`, but we have to be careful of the shapes. Here `top_class` is a 2D tensor with shape `(64, 1)` while `labels` is 1D with shape `(64)`. To get the equality to work out the way we want, `top_class` and `labels` must have the same shape.
#
# If we do
#
# ```python
# equals = top_class == labels
# ```
#
# `equals` will have shape `(64, 64)`, try it yourself. What it's doing is comparing the one element in each row of `top_class` with each element in `labels` which returns 64 True/False boolean values for each row.

# %%
equals = top_class == labels.view(*top_class.shape)

# %%
equals[:10]
# Out:
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [ True]])

# %%
equals.type()
# Out:
# 'torch.BoolTensor'

# %% [markdown]
# Now we need to calculate the percentage of correct predictions. `equals` has binary values, either 0 or 1. This means that if we just sum up all the values and divide by the number of values, we get the percentage of correct predictions. This is the same operation as taking the mean, so we can get the accuracy with a call to `torch.mean`. If only it was that simple. If you try `torch.mean(equals)`, you'll get an error
#
# ```
# RuntimeError: mean is not implemented for type torch.ByteTensor
# ```
#
# This happens because `equals` has type `torch.ByteTensor` but `torch.mean` isn't implemented for tensors with that type. So we'll need to convert `equals` to a float tensor. Note that when we take `torch.mean` it returns a scalar tensor, to get the actual value as a float we'll need to do `accuracy.item()`.

# %%
accuracy = torch.mean(equals.type(torch.FloatTensor))
print(f'Accuracy: {accuracy.item()*100}%')
# Out:
# Accuracy: 7.8125%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%. Now let's train our network and include our validation pass so we can measure how well the network is performing on the test set. Since we're not updating our parameters in the validation pass, we can speed up our code by turning off gradients using `torch.no_grad()`:
#
# ```python
# # turn off gradients
# with torch.no_grad():
#     # validation pass here
#     for images, labels in testloader:
#         ...
# ```
#
# >**Exercise:** Implement the validation loop below and print out the total accuracy after the loop. You can largely copy and paste the code from above, but I suggest typing it in because writing it out yourself is essential for building the skill. In general you'll always learn more by typing it rather than copy-pasting. You should be able to get an accuracy above 80%.

# %%
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 40
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    ## Trainnig Pass
    running_train_loss = 0
    train_acc = 0
    for images, labels in trainloader:
        
        optimizer.zero_grad()
        
        train_log_ps = model(images)
        train_loss = criterion(train_log_ps, labels)
        train_loss.backward()
        optimizer.step()
        
        train_ps = torch.exp(train_log_ps)
        train_top_p, train_top_c = torch.topk(train_ps, 1, dim=1)
        train_equals = (train_top_c == labels.view(*train_top_c.shape))
        train_acc += torch.mean(train_equals.type(torch.FloatTensor))        
        running_train_loss += train_loss.item()
        
    else:
        ## Print trainnig metrics
        print(f'Ephoch #{e+1} -----------------------------------------------------------------')
        
        train_loss = round(running_train_loss/len(trainloader), 5)
        train_losses.append(train_loss)
        train_acc /= len(trainloader)
        print(f'Trainning Loss: {train_loss}')
        print(f'Trainning Accuracy: {round(train_acc.item() * 100, 5)} %')
        
        ## Validation Pass
        ## TODO: Implement the validation pass and print out the validation accuracy
        val_accuracy = 0
        running_test_loss = 0
        for images, labels in testloader:
            log_ps = model.forward(images)
            ps = torch.exp(log_ps)
            top_p, top_c = torch.topk(ps, 1, dim=1)
            equals = (top_c == labels.view(*top_c.shape))
            val_accuracy += torch.mean(equals.type(torch.FloatTensor))
            
            loss = criterion(log_ps, labels)
            running_test_loss += loss.item()
            
        else:
            val_loss = round(running_test_loss/len(testloader), 5)
            test_losses.append(val_loss)
            val_accuracy /= len(testloader)
            print(f'\nValidation Loss: {val_loss}')
            print(f'Validation Accuracy: {round(val_accuracy.item()*100, 5)} %\n')
# Out:
# Ephoch #1 -----------------------------------------------------------------
# Trainning Loss: 0.51536
# Trainning Accuracy: 81.16338 %
#
# Validation Loss: 0.42158
# Validation Accuracy: 84.80294 %
#
# Ephoch #2 -----------------------------------------------------------------
# Trainning Loss: 0.3921
# Trainning Accuracy: 85.67264 %
#
# Validation Loss: 0.40583
# Validation Accuracy: 85.21098 %
#
# Ephoch #3 -----------------------------------------------------------------
# Trainning Loss: 0.35347
# Trainning Accuracy: 87.08022 %
#
# Validation Loss: 0.3923
# Validation Accuracy: 85.36027 %
#
# Ephoch #4 -----------------------------------------------------------------
# Trainning Loss: 0.3344
# Trainning Accuracy: 87.68823 %
#
# Validation Loss: 0.3787
# Validation Accuracy: 86.19626 %
#
# Ephoch #5 -----------------------------------------------------------------
# Trainning Loss: 0.31703
# Trainning Accuracy: 88.40618 %
#
# Validation Loss: 0.3851
# Validation Accuracy: 86.66402 %
#
# Ephoch #6 -----------------------------------------------------------------
# Trainning Loss: 0.30053
# Trainning Accuracy: 88.91758 %
#
# Validation Loss: 0.36294
# Validation Accuracy: 87.5 %
#
# Ephoch #7 -----------------------------------------------------------------
# Trainning Loss: 0.29463
# Trainning Accuracy: 89.05084 %
#
# Validation Loss: 0.37481
# Validation Accuracy: 86.69387 %
#
# Ephoch #8 -----------------------------------------------------------------
# Trainning Loss: 0.28266
# Trainning Accuracy: 89.64053 %
#
# Validation Loss: 0.36438
# Validation Accuracy: 87.25119 %
#
# Ephoch #9 -----------------------------------------------------------------
# Trainning Loss: 0.27624
# Trainning Accuracy: 89.98701 %
#
# Validation Loss: 0.36988
# Validation Accuracy: 87.41043 %
#
# Ephoch #10 -----------------------------------------------------------------
# Trainning Loss: 0.26969
# Trainning Accuracy: 90.03865 %
#
# Validation Loss: 0.40753
# Validation Accuracy: 86.50478 %
#
# Ephoch #11 -----------------------------------------------------------------
# Trainning Loss: 0.26313
# Trainning Accuracy: 90.39512 %
#
# Validation Loss: 0.37635
# Validation Accuracy: 87.73885 %
#
# Ephoch #12 -----------------------------------------------------------------
# Trainning Loss: 0.25217
# Trainning Accuracy: 90.64499 %
#
# Validation Loss: 0.36635
# Validation Accuracy: 88.07723 %
#
# Ephoch #13 -----------------------------------------------------------------
# Trainning Loss: 0.24943
# Trainning Accuracy: 90.70662 %
#
# Validation Loss: 0.36197
# Validation Accuracy: 88.01752 %
#
# Ephoch #14 -----------------------------------------------------------------
# Trainning Loss: 0.24176
# Trainning Accuracy: 91.01812 %
#
# Validation Loss: 0.39034
# Validation Accuracy: 87.18153 %
#
# Ephoch #15 -----------------------------------------------------------------
# Trainning Loss: 0.24016
# Trainning Accuracy: 91.06976 %
#
# Validation Loss: 0.37539
# Validation Accuracy: 87.85828 %
#
# Ephoch #16 -----------------------------------------------------------------
# Trainning Loss: 0.23212
# Trainning Accuracy: 91.33129 %
#
# Validation Loss: 0.39426
# Validation Accuracy: 87.41043 %
#
# Ephoch #17 -----------------------------------------------------------------
# Trainning Loss: 0.2256
# Trainning Accuracy: 91.59448 %
#
# Validation Loss: 0.39746
# Validation Accuracy: 87.918 %
#
# Ephoch #18 -----------------------------------------------------------------
# Trainning Loss: 0.22271
# Trainning Accuracy: 91.67111 %
#
# Validation Loss: 0.39411
# Validation Accuracy: 87.19148 %
#
# Ephoch #19 -----------------------------------------------------------------
# Trainning Loss: 0.2227
# Trainning Accuracy: 91.79438 %
#
# Validation Loss: 0.3772
# Validation Accuracy: 88.52508 %
#
# Ephoch #20 -----------------------------------------------------------------
# Trainning Loss: 0.20983
# Trainning Accuracy: 92.30744 %
#
# Validation Loss: 0.36622
# Validation Accuracy: 88.88336 %
#
# Ephoch #21 -----------------------------------------------------------------
# Trainning Loss: 0.21024
# Trainning Accuracy: 92.15752 %
#
# Validation Loss: 0.37056
# Validation Accuracy: 88.49522 %
#
# Ephoch #22 -----------------------------------------------------------------
# Trainning Loss: 0.20471
# Trainning Accuracy: 92.4307 %
#
# Validation Loss: 0.39138
# Validation Accuracy: 88.1469 %
#
# Ephoch #23 -----------------------------------------------------------------
# Trainning Loss: 0.2036
# Trainning Accuracy: 92.39072 %
#
# Validation Loss: 0.41492
# Validation Accuracy: 87.78862 %
#
# Ephoch #24 -----------------------------------------------------------------
# Trainning Loss: 0.2004
# Trainning Accuracy: 92.52399 %
#
# Validation Loss: 0.41296
# Validation Accuracy: 88.28623 %
#
# Ephoch #25 -----------------------------------------------------------------
# Trainning Loss: 0.20371
# Trainning Accuracy: 92.55397 %
#
# Validation Loss: 0.39192
# Validation Accuracy: 88.55494 %
#
# Ephoch #26 -----------------------------------------------------------------
# Trainning Loss: 0.19463
# Trainning Accuracy: 92.76885 %
#
# Validation Loss: 0.38318
# Validation Accuracy: 88.97293 %
#
# Ephoch #27 -----------------------------------------------------------------
# Trainning Loss: 0.1893
# Trainning Accuracy: 92.98874 %
#
# Validation Loss: 0.40491
# Validation Accuracy: 87.97771 %
#
# Ephoch #28 -----------------------------------------------------------------
# Trainning Loss: 0.19571
# Trainning Accuracy: 92.83549 %
#
# Validation Loss: 0.45534
# Validation Accuracy: 87.59952 %
#
# Ephoch #29 -----------------------------------------------------------------
# Trainning Loss: 0.19383
# Trainning Accuracy: 92.98374 %
#
# Validation Loss: 0.43895
# Validation Accuracy: 88.02747 %
#
# Ephoch #30 -----------------------------------------------------------------
# Trainning Loss: 0.18972
# Trainning Accuracy: 93.15532 %
#
# Validation Loss: 0.42237
# Validation Accuracy: 88.10709 %
#
# Ephoch #31 -----------------------------------------------------------------
# Trainning Loss: 0.17878
# Trainning Accuracy: 93.38186 %
#
# Validation Loss: 0.42358
# Validation Accuracy: 88.1668 %
#
# Ephoch #32 -----------------------------------------------------------------
# Trainning Loss: 0.17922
# Trainning Accuracy: 93.37686 %
#
# Validation Loss: 0.43617
# Validation Accuracy: 88.24642 %
#
# Ephoch #33 -----------------------------------------------------------------
# Trainning Loss: 0.1815
# Trainning Accuracy: 93.39352 %
#
# Validation Loss: 0.40216
# Validation Accuracy: 88.28623 %
#
# Ephoch #34 -----------------------------------------------------------------
# Trainning Loss: 0.17226
# Trainning Accuracy: 93.65172 %
#
# Validation Loss: 0.42977
# Validation Accuracy: 88.49522 %
#
# Ephoch #35 -----------------------------------------------------------------
# Trainning Loss: 0.17238
# Trainning Accuracy: 93.70336 %
#
# Validation Loss: 0.41774
# Validation Accuracy: 88.63456 %
#
# Ephoch #36 -----------------------------------------------------------------
# Trainning Loss: 0.16825
# Trainning Accuracy: 93.73501 %
#
# Validation Loss: 0.45305
# Validation Accuracy: 87.87819 %
#
# Ephoch #37 -----------------------------------------------------------------
# Trainning Loss: 0.17209
# Trainning Accuracy: 93.73001 %
#
# Validation Loss: 0.43756
# Validation Accuracy: 88.37579 %
#
# Ephoch #38 -----------------------------------------------------------------
# Trainning Loss: 0.16857
# Trainning Accuracy: 93.92324 %
#
# Validation Loss: 0.4401
# Validation Accuracy: 88.33598 %
#
# Ephoch #39 -----------------------------------------------------------------
# Trainning Loss: 0.16325
# Trainning Accuracy: 94.01319 %
#
# Validation Loss: 0.47581
# Validation Accuracy: 88.53503 %
#
# Ephoch #40 -----------------------------------------------------------------
# Trainning Loss: 0.15889
# Trainning Accuracy: 94.20809 %
#
# Validation Loss: 0.47134
# Validation Accuracy: 88.04737 %

# %% [markdown]
# ## Overfitting
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
#
# <img src='assets/overfitting.png' width=450px>
#
# The network learns the training set better and better, resulting in lower training losses. However, it starts having problems generalizing to data outside the training set leading to the validation loss increasing. The ultimate goal of any deep learning model is to make predictions on new data, so we should strive to get the lowest validation loss possible. One option is to use the version of the model with the lowest validation loss, here the one around 8-10 training epochs. This strategy is called *early-stopping*. In practice, you'd save the model frequently as you're training then later choose the model with the lowest validation loss.
#
# The most common method to reduce overfitting (outside of early-stopping) is *dropout*, where we randomly drop input units. This forces the network to share information between weights, increasing it's ability to generalize to new data. Adding dropout in PyTorch is straightforward using the [`nn.Dropout`](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) module.
#
# ```python
# class Classifier(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(784, 256)
#         self.fc2 = nn.Linear(256, 128)
#         self.fc3 = nn.Linear(128, 64)
#         self.fc4 = nn.Linear(64, 10)
#
#         # Dropout module with 0.2 drop probability
#         self.dropout = nn.Dropout(p=0.2)
#
#     def forward(self, x):
#         # make sure input tensor is flattened
#         x = x.view(x.shape[0], -1)
#
#         # Now with dropout
#         x = self.dropout(F.relu(self.fc1(x)))
#         x = self.dropout(F.relu(self.fc2(x)))
#         x = self.dropout(F.relu(self.fc3(x)))
#
#         # output so no dropout here
#         x = F.log_softmax(self.fc4(x), dim=1)
#
#         return x
# ```
#
# During training we want to use dropout to prevent overfitting, but during inference we want to use the entire network. So, we need to turn off dropout during validation, testing, and whenever we're using the network to make predictions. To do this, you use `model.eval()`. This sets the model to evaluation mode where the dropout probability is 0. You can turn dropout back on by setting the model to train mode with `model.train()`. In general, the pattern for the validation loop will look like this, where you turn off gradients, set the model to evaluation mode, calculate the validation loss and metric, then set the model back to train mode.
#
# ```python
# # turn off gradients
# with torch.no_grad():
#
#     # set model to evaluation mode
#     model.eval()
#
#     # validation pass here
#     for images, labels in testloader:
#         ...
#
# # set model back to train mode
# model.train()
# ```

# %% [markdown]
# > **Exercise:** Add dropout to your model and train it on Fashion-MNIST again. See if you can get a lower validation loss or higher accuracy.

# %%
## TODO: Define your model with dropout added
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
        self.dropout = nn.Dropout(p=0.2)
        
    def forward(self, x):
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %%
## TODO: Train your model with dropout, and monitor the training progress with the validation loss and accuracy
model = Network()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

ephocs = 40
train_losses, val_losses, train_accs, val_accs = [], [], [], []

for e in range(ephocs):
    t_running_loss = 0
    t_running_acc = 0
    for timages, tlabels in trainloader:
        optimizer.zero_grad()
        
        log_ps = model.forward(timages)
        ps = torch.exp(log_ps)
        loss = criterion(log_ps, tlabels)
        loss.backward()
        optimizer.step()
        
        top_p, top_c = torch.topk(ps, 1, dim=1)
        equals = (top_c == tlabels.view(*top_c.shape))
        acc = torch.mean(equals.type(torch.FloatTensor))
        
        t_running_acc += acc.item()
        t_running_loss += loss.item()
        
    else:
        train_accs.append(t_running_acc / len(trainloader))
        train_losses.append(t_running_loss / len(trainloader))
        
        with torch.no_grad():
            model.eval()       # Set model to evaluation mode
            
            v_running_loss = 0
            v_running_acc = 0            
            for vimages, vlabels in testloader:
                log_ps = model.forward(vimages)
                ps = torch.exp(log_ps)
                loss = criterion(log_ps, vlabels)

                top_p, top_c = torch.topk(ps, 1, dim=1)
                equals = (top_c == vlabels.view(*top_c.shape))
                acc = torch.mean(equals.type(torch.FloatTensor))

                v_running_acc += acc.item()
                v_running_loss += loss.item()
            else:
                val_accs.append(v_running_acc / len(testloader))
                val_losses.append(v_running_loss / len(testloader))
        
        model.train()      # Set model back to training mode
        
        print('#################################################################################')
        print(f'Epoch {e+1}/{ephocs}:')
        print('train_loss: {:.4f} - train_acc: {:.4f} ==== val_loss: {:.4f} - val_acc: {:.4f}\n'.format(train_losses[-1], train_accs[-1], val_losses[-1], val_accs[-1]))
        
# print(train_accs)
# Out:
# #################################################################################
# Epoch 1/40:
# train_loss: 0.6034 - train_acc: 0.7812 ==== val_loss: 0.4747 - val_acc: 0.8258
#
# #################################################################################
# Epoch 2/40:
# train_loss: 0.4847 - train_acc: 0.8301 ==== val_loss: 0.4329 - val_acc: 0.8430
#
# #################################################################################
# Epoch 3/40:
# train_loss: 0.4534 - train_acc: 0.8429 ==== val_loss: 0.4304 - val_acc: 0.8478
#
# #################################################################################
# Epoch 4/40:
# train_loss: 0.4373 - train_acc: 0.8461 ==== val_loss: 0.4213 - val_acc: 0.8556
#
# #################################################################################
# Epoch 5/40:
# train_loss: 0.4250 - train_acc: 0.8515 ==== val_loss: 0.3890 - val_acc: 0.8586
#
# #################################################################################
# Epoch 6/40:
# train_loss: 0.4084 - train_acc: 0.8587 ==== val_loss: 0.4116 - val_acc: 0.8561
#
# #################################################################################
# Epoch 7/40:
# train_loss: 0.4046 - train_acc: 0.8582 ==== val_loss: 0.4026 - val_acc: 0.8558
#
# #################################################################################
# Epoch 8/40:
# train_loss: 0.4000 - train_acc: 0.8605 ==== val_loss: 0.3825 - val_acc: 0.8663
#
# #################################################################################
# Epoch 9/40:
# train_loss: 0.3905 - train_acc: 0.8625 ==== val_loss: 0.4040 - val_acc: 0.8585
#
# #################################################################################
# Epoch 10/40:
# train_loss: 0.3867 - train_acc: 0.8620 ==== val_loss: 0.3956 - val_acc: 0.8581
#
# #################################################################################
# Epoch 11/40:
# train_loss: 0.3848 - train_acc: 0.8653 ==== val_loss: 0.4031 - val_acc: 0.8457
#
# #################################################################################
# Epoch 12/40:
# train_loss: 0.3767 - train_acc: 0.8695 ==== val_loss: 0.3807 - val_acc: 0.8672
#
# #################################################################################
# Epoch 13/40:
# train_loss: 0.3761 - train_acc: 0.8685 ==== val_loss: 0.3827 - val_acc: 0.8650
#
# #################################################################################
# Epoch 14/40:
# train_loss: 0.3760 - train_acc: 0.8680 ==== val_loss: 0.3916 - val_acc: 0.8641
#
# #################################################################################
# Epoch 15/40:
# train_loss: 0.3741 - train_acc: 0.8695 ==== val_loss: 0.3924 - val_acc: 0.8660
#
# #################################################################################
# Epoch 16/40:
# train_loss: 0.3721 - train_acc: 0.8702 ==== val_loss: 0.3759 - val_acc: 0.8698
#
# #################################################################################
# Epoch 17/40:
# train_loss: 0.3708 - train_acc: 0.8712 ==== val_loss: 0.3696 - val_acc: 0.8709
#
# #################################################################################
# Epoch 18/40:
# train_loss: 0.3682 - train_acc: 0.8715 ==== val_loss: 0.3788 - val_acc: 0.8699
#
# #################################################################################
# Epoch 19/40:
# train_loss: 0.3543 - train_acc: 0.8753 ==== val_loss: 0.4007 - val_acc: 0.8705
#
# #################################################################################
# Epoch 20/40:
# train_loss: 0.3594 - train_acc: 0.8740 ==== val_loss: 0.3789 - val_acc: 0.8693
#
# #################################################################################
# Epoch 21/40:
# train_loss: 0.3578 - train_acc: 0.8760 ==== val_loss: 0.3655 - val_acc: 0.8729
#
# #################################################################################
# Epoch 22/40:
# train_loss: 0.3562 - train_acc: 0.8763 ==== val_loss: 0.3809 - val_acc: 0.8711
#
# #################################################################################
# Epoch 23/40:
# train_loss: 0.3544 - train_acc: 0.8763 ==== val_loss: 0.3799 - val_acc: 0.8686
#
# #################################################################################
# Epoch 24/40:
# train_loss: 0.3594 - train_acc: 0.8761 ==== val_loss: 0.3785 - val_acc: 0.8713
#
# #################################################################################
# Epoch 25/40:
# train_loss: 0.3484 - train_acc: 0.8786 ==== val_loss: 0.3921 - val_acc: 0.8690
#
# #################################################################################
# Epoch 26/40:
# train_loss: 0.3481 - train_acc: 0.8791 ==== val_loss: 0.3751 - val_acc: 0.8747
#
# #################################################################################
# Epoch 27/40:
# train_loss: 0.3447 - train_acc: 0.8810 ==== val_loss: 0.3649 - val_acc: 0.8710
#
# #################################################################################
# Epoch 28/40:
# train_loss: 0.3537 - train_acc: 0.8752 ==== val_loss: 0.3858 - val_acc: 0.8622
#
# #################################################################################
# Epoch 29/40:
# train_loss: 0.3450 - train_acc: 0.8804 ==== val_loss: 0.3841 - val_acc: 0.8752
#
# #################################################################################
# Epoch 30/40:
# train_loss: 0.3433 - train_acc: 0.8823 ==== val_loss: 0.3869 - val_acc: 0.8712
#
# #################################################################################
# Epoch 31/40:
# train_loss: 0.3409 - train_acc: 0.8788 ==== val_loss: 0.3754 - val_acc: 0.8722
#
# #################################################################################
# Epoch 32/40:
# train_loss: 0.3394 - train_acc: 0.8814 ==== val_loss: 0.3737 - val_acc: 0.8728
#
# #################################################################################
# Epoch 33/40:
# train_loss: 0.3498 - train_acc: 0.8798 ==== val_loss: 0.3885 - val_acc: 0.8715
#
# #################################################################################
# Epoch 34/40:
# train_loss: 0.3397 - train_acc: 0.8824 ==== val_loss: 0.3743 - val_acc: 0.8692
#
# #################################################################################
# Epoch 35/40:
# train_loss: 0.3453 - train_acc: 0.8813 ==== val_loss: 0.3855 - val_acc: 0.8673
#
# #################################################################################
# Epoch 36/40:
# train_loss: 0.3362 - train_acc: 0.8834 ==== val_loss: 0.3904 - val_acc: 0.8702
#
# #################################################################################
# Epoch 37/40:
# train_loss: 0.3310 - train_acc: 0.8842 ==== val_loss: 0.3982 - val_acc: 0.8625
#
# #################################################################################
# Epoch 38/40:
# train_loss: 0.3323 - train_acc: 0.8840 ==== val_loss: 0.3585 - val_acc: 0.8781
#
# #################################################################################
# Epoch 39/40:
# train_loss: 0.3393 - train_acc: 0.8825 ==== val_loss: 0.3789 - val_acc: 0.8787
#
# #################################################################################
# Epoch 40/40:
# train_loss: 0.3415 - train_acc: 0.8827 ==== val_loss: 0.3842 - val_acc: 0.8761

# %%
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_accs, label='Training Accuracy')
plt.plot(val_accs, label='Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it for inference. We've done this before, but now we need to remember to set the model in inference mode with `model.eval()`. You'll also want to turn off autograd with the `torch.no_grad()` context.

# %%
# Import helper module (should be in the repo)
import helper

# Test out your network!

model.eval()

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Plot the image and probabilities
helper.view_classify(img.view(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# ## Next Up!
#
# In the next part, I'll show you how to save your trained models. In general, you won't want to train a model everytime you need it. Instead, you'll train once, save it, then load the model when you want to train more or use if for inference.
